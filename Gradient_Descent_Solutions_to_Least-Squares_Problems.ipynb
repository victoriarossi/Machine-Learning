# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
## DO NOT Change
def graddescent(X,y,tau,w_init,it):
    """
    compute 10 iterations of gradient descent starting at w1
    w_{k+1}= w_k - tau*X'*(X*w_k - y)
    """
    W = np.zeros((w_init.shape[0],it))
    W[:,[0]] = w_init
    for k in range(it-1):
        W[:,[k+1]] = W[:,[k]] - tau * X.T @ (X @ W[:,[k]] - y)
    return W

# %% [markdown]
# # Question 1b)

# %%
U = np.array([[1, 0], [0, 1], [0, 0], [0, 0]])
S = np.array([[1, 0], [0, 0.5]])
Sinv = np.linalg.inv(S)
V = np.eye(2)
X = U @ S @ V.T
y = np.array([[1], [0.5], [1], [0]])
yt = y.transpose()
XT = X.transpose()

print("w_ls: " ,np.linalg.inv(XT@X)@XT@y)
print("c : ", yt@y - yt@X@np.linalg.inv(XT@X)@XT@y)

### Find Least Squares Solution
w_ls = V @ Sinv @ U.T @ y
c = y.T @ y - y.T @ X @ w_ls

### Find values of f(w), the contour plot surface for 
w1 = np.arange(-1,3,.1)
w2 = np.arange(-1,3,.1)
fw = np.zeros((len(w1), len(w2)))
for i in range(len(w2)):
    for j in range(len(w1)):
        w = np.array([ [w1[j]], [w2[i]] ])
        fw[i,j] = (w-w_ls).T @ X.T @ X @ (w-w_ls) + c

### Plot the countours
plt.figure(num=None, figsize=(4, 4), dpi=120)      
plt.contour(w1,w2,fw,20)
plt.xlim([-1,3])
plt.ylim([-1,3])
plt.xlabel('$w_1$')
plt.ylabel('$w_2$')
plt.axis('square')
# Out:
# w_ls:  [[1.]
#  [1.]]
# c :  [[1.]]
# (-1.0, 2.899999999999999, -1.0, 2.899999999999999)

# %% [markdown]
# # Question 1c)

# %%
U = np.array([[1, 0], [0, 1], [0, 0], [0, 0]])
S = np.array([[1, 0], [0, 0.2]])
Sinv = np.linalg.inv(S)
V = np.eye(2)
X = U @ S @ V.T
y = np.array([[1], [0.2], [1], [0]])
yt = y.transpose()
XT = X.transpose()

print("w_ls: " ,np.linalg.inv(XT@X)@XT@y)
print("c : ", yt@y - yt@X@np.linalg.inv(XT@X)@XT@y)

### Find Least Squares Solution
w_ls = V @ Sinv @ U.T @ y
c = y.T @ y - y.T @ X @ w_ls

### Find values of f(w), the contour plot surface for 
w1 = np.arange(-1,3,.1)
w2 = np.arange(-1,3,.1)
fw = np.zeros((len(w1), len(w2)))
for i in range(len(w2)):
    for j in range(len(w1)):
        w = np.array([ [w1[j]], [w2[i]] ])
        fw[i,j] = (w-w_ls).T @ X.T @ X @ (w-w_ls) + c

### Plot the countours
plt.figure(num=None, figsize=(4, 4), dpi=120)      
plt.contour(w1,w2,fw,20)
plt.xlim([-1,3])
plt.ylim([-1,3])
plt.xlabel('$w_1$')
plt.ylabel('$w_2$')
plt.axis('square')
# As we changed S and y we can see that the countour is straighten.
# Out:
# w_ls:  [[1.]
#  [1.]]
# c :  [[1.]]
# (-1.0, 2.899999999999999, -1.0, 2.899999999999999)

# %% [markdown]
# # Question 1d)

# %%
U = np.array([[1, 0], [0, 1], [0, 0], [0, 0]])
S = np.array([[1, 0], [0, 0.5]])
Sinv = np.linalg.inv(S)
V = (1.0/math.sqrt(2))*np.array([[1, 1], [1, -1]])
X = U @ S @ V.T
y = np.array([[math.sqrt(2)], [0], [1], [0]])
yt = y.transpose()
XT = X.transpose()

print("w_ls: " ,np.linalg.inv(XT@X)@XT@y)
print("c : ", yt@y - yt@X@np.linalg.inv(XT@X)@XT@y)

### Find Least Squares Solution
w_ls = V @ Sinv @ U.T @ y
c = y.T @ y - y.T @ X @ w_ls

### Find values of f(w), the contour plot surface for 
w1 = np.arange(-1,3,.1)
w2 = np.arange(-1,3,.1)
fw = np.zeros((len(w1), len(w2)))
for i in range(len(w2)):
    for j in range(len(w1)):
        w = np.array([ [w1[j]], [w2[i]] ])
        fw[i,j] = (w-w_ls).T @ X.T @ X @ (w-w_ls) + c

w_0_i = np.array([[2],[2]])
w_0_ii = np.array([[0],[2]])
w_0_iii = np.array([[2],[1]])

gradient_i = 2*XT@X@w_0_i - 2*XT@y
gradient_ii = 2*XT@X@w_0_ii - 2*XT@y
gradient_iii = 2*XT@X@w_0_iii - 2*XT@y

### Plot the countours
plt.figure(num=None, figsize=(4, 4), dpi=120) 
# plt.quiver(*origin, w_0_i[:,0], w_0_i,color=['r','g','b'])
plt.arrow(w_0_i[0][0],w_0_i[1][0],gradient_i[0][0],gradient_i[1][0],width = 0.05,color='r')
plt.arrow(w_0_ii[0][0],w_0_ii[1][0],gradient_ii[0][0],gradient_ii[1][0],width = 0.05,color='b')
plt.arrow(w_0_iii[0][0],w_0_iii[1][0],gradient_iii[0][0],gradient_iii[1][0],width = 0.05,color='g')
plt.contour(w1,w2,fw,20)
plt.xlim([-1,3])
plt.ylim([-1,3])
plt.xlabel('$w_1$')
plt.ylabel('$w_2$')
plt.axis('square')
# Now if we change the right singular vectors then the countour is shifted to the right
# Out:
# w_ls:  [[1.]
#  [1.]]
# c :  [[1.]]
# (-1.0, 4.41705397705532, -1.0, 4.41705397705532)

# %% [markdown]
# # Question 2b)

# %%
U = np.array([[1, 0], [0, 1], [0, 0], [0, 0]])
S = np.array([[1, 0], [0, 0.5]])
Sinv = np.linalg.inv(S)
V = 1/np.sqrt(2)*np.array([[1, 1], [1, -1]])
X = U @ S @ V.T
y = np.array([[np.sqrt(2)], [0], [1], [0]])

### Find Least Squares Solution
w_ls = V @ Sinv @ U.T @ y
c = y.T @ y - y.T @ X @ w_ls

### Find values of f(w), the contour plot surface for 
w1 = np.arange(-1,3,.1)
w2 = np.arange(-1,3,.1)
fw = np.zeros((len(w1), len(w2)))
for i in range(len(w1)):
    for j in range(len(w2)):
        w = np.array([ [w1[i]], [w2[j]] ])
        fw[i,j] = (w-w_ls).T @ X.T @ X @ (w-w_ls) + c

# %%
# w_init = np.array([[1.5],[-0.5]])  # complete this line with a 2x1 numpy array for the values specified in the activity
# w_init = np.array([[0],[0]])
w_init = np.array([[0],[2]])
it = 20
tau = .5
W = graddescent(X,y,tau,w_init,it)

### Create plot
plt.figure(num=None, figsize=(4, 4), dpi=120) 
plt.contour(w1,w2,fw,20)
plt.plot(w_ls[0],w_ls[1],"s", label="LS Solution")
plt.plot(W[0,:],W[1,:],'o-',linewidth=2, label="Gradient Descent")
plt.legend()
plt.xlim([-1,3])
plt.xlabel('$w_1$')
plt.ylim([-1,3])
plt.ylabel('$w_2$')
plt.title(r'$\tau = .5$')
plt.axis('square')

# It's shaped that why because each step is getting closer to the LS Solution (the center)
# If we start with w = [0 0]^T then the gradient descent seems like a line ascending from the (0,0) towards the center (1,1)
# If we start with w = [0 2]^T then the gradient descent seems like a line descending from the (0,2) towards the center (1,1)
# Out:
# (-1.0, 2.899999999999999, -1.0, 2.899999999999999)

# %% [markdown]
# # Question 2c)

# %%
# copy and paste code from above
w_init = np.array([[1.5],[-0.5]])  # complete this line with a 2x1 numpy array for the values specified in the activity
it = 20
tau = 2.5
W = graddescent(X,y,tau,w_init,it)


### Create plot
plt.figure(num=None, figsize=(4, 4), dpi=120)
plt.contour(w1,w2,fw,20)
plt.plot(w_ls[0],w_ls[1],"s", label="LS Solution")
plt.plot(W[0,:],W[1,:],'o-',linewidth=2, label="Gradient Descent")
plt.legend()
plt.xlim([-1,3])
plt.xlabel('$w_1$')
plt.ylim([-1,3])
plt.ylabel('$w_2$')
plt.title(r'$\tau = 2.5$')
plt.axis('square')
# tau is too big so there is no convengence
# Out:
# (-830.3141824977304,
#  1201.7871525657204,
#  -830.3141825420869,
#  1201.7871525213639)

# %% [markdown]
# # Question 2d)

# %%
U = np.array([[1, 0], [0, 1], [0, 0], [0, 0]])
S = np.array([[1, 0], [0, 0.25]])
Sinv = np.linalg.inv(S)
V = 1/np.sqrt(2)*np.array([[1, 1], [1, -1]])
X = U @ S @ V.T
y = np.array([[np.sqrt(2)], [0], [1], [0]])

### Find Least Squares Solution
w_ls = V @ Sinv @ U.T @ y
c = y.T @ y - y.T @ X @ w_ls

### Find values of f(w), the contour plot surface for 
w1 = np.arange(-1,3,.1)
w2 = np.arange(-1,3,.1)
fw = np.zeros((len(w1), len(w2)))
for i in range(len(w1)):
    for j in range(len(w2)):
        w = np.array([ [w1[i]], [w2[j]] ])
        fw[i,j] = (w-w_ls).T @ X.T @ X @ (w-w_ls) + c

# %%
w_init = np.array([[1.5],[-0.5]])  # complete this line with a 2x1 numpy array for the values specified in the activity
it = 20
tau = .5
W = graddescent(X,y,tau,w_init,it)

### Create plot
plt.figure(num=None, figsize=(4, 4), dpi=120) 
plt.contour(w1,w2,fw,20)
plt.plot(w_ls[0],w_ls[1],"s", label="LS Solution")
plt.plot(W[0,:],W[1,:],'o-',linewidth=2, label="Gradient Descent")
plt.legend()
plt.xlim([-1,3])
plt.xlabel('$w_1$')
plt.ylim([-1,3])
plt.ylabel('$w_2$')
plt.title(r'$\tau = .5$')
plt.axis('square')
# The cost function straigthen as we increase the difference between the values of S.
# The further steps seems to be smaller. The first step is the same but the following once are closer to each other. 
# So it never reaches the center
# Out:
# (-1.0, 2.899999999999999, -1.0, 2.899999999999999)

# %%
# e) 
# If we change the ratio of the singular values the shape of the cost function might vary making it more straighten or in a more 
# circular way. The optimum is defined as 2/||X||_op = 2/{the largest singular value} => if we increase the ratio then the number of 
# iterations needed will increase. For example in question 2.d) we will need approx 80/90 iterations.
